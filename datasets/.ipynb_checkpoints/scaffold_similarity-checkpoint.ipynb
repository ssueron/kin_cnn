# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from rdkit import Chem
from rdkit.Chem import AllChem
from rdkit import DataStructs
from rdkit.Chem.rdFingerprintGenerator import GetMorganGenerator

df = pd.read_csv("chembl_pretraining.csv")
smiles_column = "Smiles"

df["mol"] = df[smiles_column].apply(Chem.MolFromSmiles)

df = df[df["mol"].notna()].reset_index(drop=True)

generator = GetMorganGenerator(radius=3, fpSize=2048)
df["ecfp6"] = df["mol"].apply(generator.GetFingerprint)

n = len(df)
fps = list(df["ecfp6"])

# Create a memory-mapped array on disk
sim_matrix = np.memmap("tanimoto_sim_matrix.dat", dtype="float32", mode="w+", shape=(n, n))

for i in range(n):
    sims = DataStructs.BulkTanimotoSimilarity(fps[i], fps)
    sim_matrix[i, :] = sims
    if i % 500 == 0:
        print(f"Processed row {i}/{n}")
# Out:
# Processed row 0/79492
# Processed row 500/79492
# Processed row 1000/79492
# Processed row 1500/79492
# Processed row 2000/79492
# Processed row 2500/79492
# Processed row 3000/79492
# Processed row 3500/79492
# Processed row 4000/79492
# Processed row 4500/79492
# Processed row 5000/79492
# Processed row 5500/79492
# Processed row 6000/79492
# Processed row 6500/79492
# Processed row 7000/79492
# Processed row 7500/79492
# Processed row 8000/79492
# Processed row 8500/79492
# Processed row 9000/79492
# Processed row 9500/79492
# Processed row 10000/79492
# Processed row 10500/79492
# Processed row 11000/79492
# Processed row 11500/79492
# Processed row 12000/79492
# Processed row 12500/79492
# Processed row 13000/79492
# Processed row 13500/79492
# Processed row 14000/79492
# Processed row 14500/79492
# Processed row 15000/79492
# Processed row 15500/79492
# Processed row 16000/79492
# Processed row 16500/79492
# Processed row 17000/79492
# Processed row 17500/79492
# Processed row 18000/79492
# Processed row 18500/79492
# Processed row 19000/79492
# Processed row 19500/79492
# Processed row 20000/79492
# Processed row 20500/79492
# Processed row 21000/79492
# Processed row 21500/79492
# Processed row 22000/79492
# Processed row 22500/79492
# Processed row 23000/79492
# Processed row 23500/79492
# Processed row 24000/79492
# Processed row 24500/79492
# Processed row 25000/79492
# Processed row 25500/79492
# Processed row 26000/79492
# Processed row 26500/79492
# Processed row 27000/79492
# Processed row 27500/79492
# Processed row 28000/79492
# Processed row 28500/79492
# Processed row 29000/79492
# Processed row 29500/79492
# Processed row 30000/79492
# Processed row 30500/79492
# Processed row 31000/79492
# Processed row 31500/79492
# Processed row 32000/79492
# Processed row 32500/79492
# Processed row 33000/79492
# Processed row 33500/79492
# Processed row 34000/79492
# Processed row 34500/79492
# Processed row 35000/79492
# Processed row 35500/79492
# Processed row 36000/79492
# Processed row 36500/79492
# Processed row 37000/79492
# Processed row 37500/79492
# Processed row 38000/79492
# Processed row 38500/79492
# Processed row 39000/79492
# Processed row 39500/79492
# Processed row 40000/79492
# Processed row 40500/79492
# Processed row 41000/79492
# Processed row 41500/79492
# Processed row 42000/79492
# Processed row 42500/79492
# Processed row 43000/79492
# Processed row 43500/79492
# Processed row 44000/79492
# Processed row 44500/79492
# Processed row 45000/79492
# Processed row 45500/79492
# Processed row 46000/79492
# Processed row 46500/79492
# Processed row 47000/79492
# Processed row 47500/79492
# Processed row 48000/79492
# Processed row 48500/79492
# Processed row 49000/79492
# Processed row 49500/79492
# Processed row 50000/79492
# Processed row 50500/79492
# Processed row 51000/79492
# Processed row 51500/79492
# Processed row 52000/79492
# Processed row 52500/79492
# Processed row 53000/79492
# Processed row 53500/79492
# Processed row 54000/79492
# Processed row 54500/79492
# Processed row 55000/79492
# Processed row 55500/79492
# Processed row 56000/79492
# Processed row 56500/79492
# Processed row 57000/79492
# Processed row 57500/79492
# Processed row 58000/79492
# Processed row 58500/79492
# Processed row 59000/79492
# Processed row 59500/79492
# Processed row 60000/79492
# Processed row 60500/79492
# Processed row 61000/79492
# Processed row 61500/79492
# Processed row 62000/79492
# Processed row 62500/79492
# Processed row 63000/79492
# Processed row 63500/79492
# Processed row 64000/79492
# Processed row 64500/79492
# Processed row 65000/79492
# Processed row 65500/79492
# Processed row 66000/79492
# Processed row 66500/79492
# Processed row 67000/79492
# Processed row 67500/79492
# Processed row 68000/79492
# Processed row 68500/79492
# Processed row 69000/79492
# Processed row 69500/79492
# Processed row 70000/79492
# Processed row 70500/79492
# Processed row 71000/79492
# Processed row 71500/79492
# Processed row 72000/79492
# Processed row 72500/79492
# Processed row 73000/79492
# Processed row 73500/79492
# Processed row 74000/79492
# Processed row 74500/79492
# Processed row 75000/79492
# Processed row 75500/79492
# Processed row 76000/79492
# Processed row 76500/79492
# Processed row 77000/79492
# Processed row 77500/79492
# Processed row 78000/79492
# Processed row 78500/79492
# Processed row 79000/79492

# %%
# Reload the similarity matrix
n = len(df)
sim_matrix = np.memmap("tanimoto_sim_matrix.dat", dtype="float32", mode="r", shape=(n, n))

# Remove diagonal (self-similarity = 1)
mask = ~np.eye(n, dtype=bool)
sims = sim_matrix[mask]

# Plot
plt.hist(sims, bins=100)
plt.xlabel("Tanimoto similarity")
plt.ylabel("Number of pairs")
plt.title("Similarity distribution (off-diagonal)")
plt.grid(True)
plt.show()

# %%
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

fps_array = np.array([np.array(fp) for fp in df["ecfp6"][:5000]])  # limit to 5k for speed
tsne = TSNE(n_components=2, metric="jaccard", perplexity=50)
coords = tsne.fit_transform(fps_array)

plt.scatter(coords[:, 0], coords[:, 1], alpha=0.6, s=3)
plt.title("t-SNE of ECFP6 Fingerprints")
plt.show()
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/metrics/pairwise.py:2361: DataConversionWarning: Data was converted to boolean for metric jaccard
#   warnings.warn(msg, DataConversionWarning)

# %%
from rdkit.ML.Cluster import Butina
from rdkit import DataStructs

def cluster_fps(fps, cutoff=0.7):
    # Compute distance matrix (1 - Tanimoto)
    dists = []
    for i in range(1, len(fps)):
        sims = DataStructs.BulkTanimotoSimilarity(fps[i], fps[:i])
        dists.extend([1 - x for x in sims])
    # Butina clustering
    clusters = Butina.ClusterData(dists, len(fps), cutoff, isDistData=True)
    return clusters

# %%
fps = list(df["ecfp6"])
clusters = cluster_fps(fps, cutoff=0.7)
print(f"Found {len(clusters)} clusters")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 fps = list(df["ecfp6"])
#       2 clusters = cluster_fps(fps, cutoff=0.7)
#       3 print(f"Found {len(clusters)} clusters")
#
# NameError: name 'df' is not defined
